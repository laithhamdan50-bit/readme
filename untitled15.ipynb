# %% [markdown]
# <a href="https://colab.research.google.com/github/laithhamdan50-bit/readme/blob/main/untitled15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('/traffic (1).csv')
data
# Out:
#              Time  Date Day of the week  CarCount  BikeCount  BusCount  \
# 0     12:00:00 AM    10         Tuesday        31          0         4
# 1     12:15:00 AM    10         Tuesday        49          0         3
# 2     12:30:00 AM    10         Tuesday        46          0         3
# 3     12:45:00 AM    10         Tuesday        51          0         2
# 4      1:00:00 AM    10         Tuesday        57          6        15
# ...           ...   ...             ...       ...        ...       ...
# 2971  10:45:00 PM     9        Thursday        16          3         1
# 2972  11:00:00 PM     9        Thursday        11          0         1
# 2973  11:15:00 PM     9        Thursday        15          4         1
# 2974  11:30:00 PM     9        Thursday        16          5         0
# 2975  11:45:00 PM     9        Thursday        14          3         1
#
#       TruckCount  Total Traffic Situation
# 0              4     39               low
# ...

# %%
data.shape
# Out:
# (2976, 9)

# %%
data.head()
# Out:
#           Time  Date Day of the week  CarCount  BikeCount  BusCount  \
# 0  12:00:00 AM    10         Tuesday        31          0         4
# 1  12:15:00 AM    10         Tuesday        49          0         3
# 2  12:30:00 AM    10         Tuesday        46          0         3
# 3  12:45:00 AM    10         Tuesday        51          0         2
# 4   1:00:00 AM    10         Tuesday        57          6        15
#
#    TruckCount  Total Traffic Situation
# 0           4     39               low
# 1           3     55               low
# 2           6     55               low
# 3           5     58               low
# 4          16     94            normal

# %%
data.tail()
# Out:
#              Time  Date Day of the week  CarCount  BikeCount  BusCount  \
# 2971  10:45:00 PM     9        Thursday        16          3         1
# 2972  11:00:00 PM     9        Thursday        11          0         1
# 2973  11:15:00 PM     9        Thursday        15          4         1
# 2974  11:30:00 PM     9        Thursday        16          5         0
# 2975  11:45:00 PM     9        Thursday        14          3         1
#
#       TruckCount  Total Traffic Situation
# 2971          36     56            normal
# 2972          30     42            normal
# 2973          25     45            normal
# 2974          27     48            normal
# 2975          15     33            normal

# %%
data.columns
# Out:
# Index(['Time', 'Date', 'Day of the week', 'CarCount', 'BikeCount', 'BusCount',
#        'TruckCount', 'Total', 'Traffic Situation'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2976 entries, 0 to 2975
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Time               2976 non-null   object
#  1   Date               2976 non-null   int64
#  2   Day of the week    2976 non-null   object
#  3   CarCount           2976 non-null   int64
#  4   BikeCount          2976 non-null   int64
#  5   BusCount           2976 non-null   int64
#  6   TruckCount         2976 non-null   int64
#  7   Total              2976 non-null   int64
#  8   Traffic Situation  2976 non-null   object
# dtypes: int64(6), object(3)
# memory usage: 209.4+ KB

# %%
data.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
from typing import Mapping
Mapping={'normal':0,'heavy':1,'high':2,'low':3}
data[ 'Traffic Situation ']=data['Traffic Situation'].replace(Mapping)
# Out:
# /tmp/ipython-input-2588722899.py:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[ 'Traffic Situation ']=data['Traffic Situation'].replace(Mapping)

# %%
from sklearn.preprocessing import LabelEncoder
LabelEncoder=LabelEncoder()
data['Traffic Situation']=LabelEncoder.fit_transform(data['Traffic Situation'])

# %%
data
# Out:
#              Time  Date Day of the week  CarCount  BikeCount  BusCount  \
# 0     12:00:00 AM    10         Tuesday        31          0         4
# 1     12:15:00 AM    10         Tuesday        49          0         3
# 2     12:30:00 AM    10         Tuesday        46          0         3
# 3     12:45:00 AM    10         Tuesday        51          0         2
# 4      1:00:00 AM    10         Tuesday        57          6        15
# ...           ...   ...             ...       ...        ...       ...
# 2971  10:45:00 PM     9        Thursday        16          3         1
# 2972  11:00:00 PM     9        Thursday        11          0         1
# 2973  11:15:00 PM     9        Thursday        15          4         1
# 2974  11:30:00 PM     9        Thursday        16          5         0
# 2975  11:45:00 PM     9        Thursday        14          3         1
#
#       TruckCount  Total  Traffic Situation  Traffic Situation
# ...

# %%
data
# Out:
#              Time  Date Day of the week  CarCount  BikeCount  BusCount  \
# 0     12:00:00 AM    10         Tuesday        31          0         4
# 1     12:15:00 AM    10         Tuesday        49          0         3
# 2     12:30:00 AM    10         Tuesday        46          0         3
# 3     12:45:00 AM    10         Tuesday        51          0         2
# 4      1:00:00 AM    10         Tuesday        57          6        15
# ...           ...   ...             ...       ...        ...       ...
# 2971  10:45:00 PM     9        Thursday        16          3         1
# 2972  11:00:00 PM     9        Thursday        11          0         1
# 2973  11:15:00 PM     9        Thursday        15          4         1
# 2974  11:30:00 PM     9        Thursday        16          5         0
# 2975  11:45:00 PM     9        Thursday        14          3         1
#
#       TruckCount  Total  Traffic Situation  Traffic Situation
# ...

# %%
data['Day of the week'].value_counts()
# Out:
# Day of the week
# Tuesday      480
# Wednesday    480
# Thursday     480
# Friday       384
# Saturday     384
# Sunday       384
# Monday       384
# Name: count, dtype: int64

# %%
d={'Saturday':0,'Sunday':1,'Monday':2,'Tuesday':3,'Wednesday':4,'Thursday':5,'Friday':6}
data['Day of the week']=data['Day of the week'].replace(d)
# Out:
# /tmp/ipython-input-2935727715.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['Day of the week']=data['Day of the week'].replace(d)

# %%
data['Day of the week']
# Out:
# 0       3
# 1       3
# 2       3
# 3       3
# 4       3
#        ..
# 2971    5
# 2972    5
# 2973    5
# 2974    5
# 2975    5
# Name: Day of the week, Length: 2976, dtype: int64

# %%
data['Time']=pd.to_datetime(data['Time'])
data['Hour']=data['Time'].dt.hour
data['Minute']=data['Time'].dt.minute
data.drop(axis=1,columns='Time',inplace=True)
# Out:
# /tmp/ipython-input-1186928407.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data['Time']=pd.to_datetime(data['Time'])

# %%
data
# Out:
#       Date  Day of the week  CarCount  BikeCount  BusCount  TruckCount  Total  \
# 0       10                3        31          0         4           4     39
# 1       10                3        49          0         3           3     55
# 2       10                3        46          0         3           6     55
# 3       10                3        51          0         2           5     58
# 4       10                3        57          6        15          16     94
# ...    ...              ...       ...        ...       ...         ...    ...
# 2971     9                5        16          3         1          36     56
# 2972     9                5        11          0         1          30     42
# 2973     9                5        15          4         1          25     45
# 2974     9                5        16          5         0          27     48
# 2975     9                5        14          3         1          15     33
#
# ...

# %%
for col in data.columns:
  plt.figure(figsize=(8,5))
  plt.hist(data[col].dropna(),bins=10,color='blue',edgecolor='red')
  plt.xlabel(col)
  plt.ylabel('Frequency')
  plt.show()

# %%
plt.pie(data['Traffic Situation'].value_counts(),labels=data['Traffic Situation'].value_counts().index,autopct='%1.1f%%',colors=['red','blue','black','yellow'],explode=(0.1,0,0.1,0))
plt.title('traffic Situation distrib')
plt.show()

# %%
data
# Out:
#       Date  Day of the week  CarCount  BikeCount  BusCount  TruckCount  Total  \
# 0       10                3        31          0         4           4     39
# 1       10                3        49          0         3           3     55
# 2       10                3        46          0         3           6     55
# 3       10                3        51          0         2           5     58
# 4       10                3        57          6        15          16     94
# ...    ...              ...       ...        ...       ...         ...    ...
# 2971     9                5        16          3         1          36     56
# 2972     9                5        11          0         1          30     42
# 2973     9                5        15          4         1          25     45
# 2974     9                5        16          5         0          27     48
# 2975     9                5        14          3         1          15     33
#
# ...

# %%
group=data[['CarCount','BikeCount','BusCount','TruckCount']].sum()
plt.figure(figsize=(10,6))
plt.pie(group,labels=group.index,autopct='%1.1f%%',colors=['red','blue','black','yellow'],explode=(0.1,0,0.1,0))
plt.title('vehicle type distribution')
plt.show()

# %%
avg=data.groupby('Day of the week')['Total'].mean()
plt.figure(figsize=(8,5))
plt.bar(avg.index,avg.values,color='red')
plt.xlabel('Day of the week')
plt.ylabel('Average Total traffic of the day')
plt.show()

# %% [markdown]
# **seborn**
#
# ```
# # This is formatted as code
# ```

# %%
vechile_count=data.groupby('Day of the week')[['CarCount','BikeCount','BusCount','TruckCount']].sum()
vechile_count.plot(kind='bar',figsize=(10,6),color=('black','blue','red','green'))
plt.title('Total vehicle count by day of the week')
plt.xlabel('Day of the week')
plt.ylabel('Total vehicle count')
plt.show()

# %%
colors=sns.color_palette('bright')
plt.pie(data['Traffic Situation'].value_counts(),labels=data['Traffic Situation'].value_counts().index,autopct='%1.1f%%',colors=colors,shadow=True,startangle=90,explode=(0.1,0,0.1,0))
plt.title('traffic Situation distrib')
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.barplot(data=data,x='Day of the week',y='Total',ci=None,palette='Blues')
plt.xlabel('Day of the week')
plt.ylabel('Average Total traffic of the day')
plt.show()
# Out:
# /tmp/ipython-input-44682205.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=data,x='Day of the week',y='Total',ci=None,palette='Blues')
# /tmp/ipython-input-44682205.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=data,x='Day of the week',y='Total',ci=None,palette='Blues')

# %%
avg=data.groupby('Day of the week')['Total'].mean()
plt.figure(figsize=(8,5))
plt.pie(avg.values,labels=avg.index,autopct='%1.1f%%',startangle=90)
plt.title('Average Total traffic of the day')
plt.show()

# %%
columns=['CarCount','BikeCount','BusCount','TruckCount']
sns.boxplot(data[columns])
plt.title('distribution')
plt.show()

# %%
for column in data.columns:
  plt.figure(figsize=(5,5))
  data.boxplot(column=column)
  plt.title(f"boxplot of {column}")
  plt.show()

# %%
data.columns
# Out:
# Index(['Date', 'Day of the week', 'CarCount', 'BikeCount', 'BusCount',
#        'TruckCount', 'Total', 'Traffic Situation', 'Traffic Situation ',
#        'Hour', 'Minute'],
#       dtype='object')

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x='Traffic Situation',y='CarCount',data=data,color='red')
plt.xlabel('Traffic Situation')
plt.ylabel('Car Count')
plt.show()

# %%
data
# Out:
#       Date  Day of the week  CarCount  BikeCount  BusCount  TruckCount  Total  \
# 0       10                3        31          0         4           4     39
# 1       10                3        49          0         3           3     55
# 2       10                3        46          0         3           6     55
# 3       10                3        51          0         2           5     58
# 4       10                3        57          6        15          16     94
# ...    ...              ...       ...        ...       ...         ...    ...
# 2971     9                5        16          3         1          36     56
# 2972     9                5        11          0         1          30     42
# 2973     9                5        15          4         1          25     45
# 2974     9                5        16          5         0          27     48
# 2975     9                5        14          3         1          15     33
#
# ...

# %%
sns.lineplot(x='Hour',y='Total',data=data,color='red')
plt.xlabel('Hour')
plt.ylabel('Total')
plt.show()

# %%
sns.lineplot(x='Hour',y='CarCount',data=data,color='red')
plt.xlabel('Hour')
plt.ylabel('CarCount')
plt.show()

# %%
sns.heatmap(data.corr(),annot=True,fmt='.2f',cmap='rainbow')
plt.xlabel('features')
plt.ylabel('features')
plt.title('correlation heatmap')
plt.show()
